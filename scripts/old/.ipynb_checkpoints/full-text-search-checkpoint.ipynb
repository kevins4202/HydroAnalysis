# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import os
import seaborn as sns
import re
import requests

# %matplotlib inline

# %%
papers = pd.read_csv(os.getcwd().replace('scripts', 'data') + '/metadata_accessible.csv')

# %%
kwords = pd.read_csv(os.getcwd().replace('scripts', 'data')+'/technical_buzzwords.csv')
words = pd.DataFrame(columns = ['topic', 'keywords'])
for i in range(kwords.shape[0]):
    words.loc[len(words.index)] = [kwords.iat[i,0], kwords.iat[i,1].split(", ")]

# %%
word_contexts = pd.read_csv(os.getcwd().replace('scripts', 'data') + '/word_contexts.csv')

# %%
keys = [
        "e3fa6eb97964b552119ea5fc78093789",
"c7cdff212e1739790e728a85953e58d",
"c515ad531ff5767f6b85a20e2c190ca9",
"ef2e9e7f3bda7235f0c079cb38fd2a9a",
"f61a0ca8673900c9539e5b3228c95a51"]

# %%
def find_keywords(k_list, abstract):
    ret = []
    
    old_abstract = abstract
    
    orig = old_abstract
    
    for word in k_list:
        word = word.lower().replace('-', ' ')
        curr_abstract = old_abstract
        c_orig = orig
        done = False
        while(True):
            if done:
                break
            try:
                found_i = curr_abstract.index(word)

                l_b = max(0, found_i - 100)
                u_b = min(len(curr_abstract), found_i+len(word)+100)
                
                if(l_b > u_b):
                    break
                try:
                    ret.append([word,c_orig[l_b:u_b]])
                except TypeError:
                    print(c_orig)
                    print(l_b + " " + u_b)
                
#                 print(word + " "+ curr_abstract[l_b:u_b])
                
                if(u_b == len(curr_abstract)):
                    break
                
                curr_abstract = curr_abstract[found_i + len(word):]
                c_orig = c_orig[found_i + len(word):]

            except ValueError:
                done = True
                continue
    
    
    return ret#returns the specific word & context

# %%
other = pd.read_csv(os.getcwd().replace('scripts', 'data') + '/papers_other_error.csv')['index'].tolist()
no_data = []

# %%
keyi = 0

# %%
#get the full text
def fullText(i, keyi):
    doi = papers.iat[i,4]
#     done = False
#     print(doi)
    try:
        js = requests.get(
            f"https://api.elsevier.com/content/article/doi/{doi}",
            headers = {"X-ELS-APIKey":keys[keyi], "Accept":"application/json"}

,
        )
        
        r = js.json()

        full_text = r['full-text-retrieval-response']['originalText']
#         full_text = re.sub(r'^https?:\/\/.[^\s]+', '', full_text)
#         print(full_text)
        
        abstr = r['full-text-retrieval-response']['coredata']['dc:description'][:25]
        
        index = full_text.find(abstr)
        if(index==-1):
            other.append(i)
            return None
        full_text = full_text[index:]
        
        full_text = ''.join(full_text.split('References')[:-1])
        
        

        full_text = full_text.lower().replace('/', ' ').replace('-', ' ').replace('\'', ' ').replace('_', ' ').replace('.', ' ').replace('(', '').replace(')', '').replace('*', '').replace(',', '')
    
#         print(full_text)
        
        return full_text
    except Exception as e:
        if js.status_code == 404:
            no_data.append(i)
        elif js.status_code ==429:
            print(str(e))
            return fullText(i, key = (keyi+1)%5)
        

        else:
            other.append(i)
        return None

# %%
for i in range(17512,papers.shape[0]):
    print(i)
    ft = fullText(i, keyi)
    
    if ft == None:
        continue
#     print(ft)
    for j in range(words.shape[0]):
        subterms = words.iat[j, 1]
#         print(subterms)
        for found in find_keywords(subterms, ft):
            contexts.append(found[1])
            word_contexts.loc[len(word_contexts.index)] = [i, words.iat[j,0], found[0]]
# Out:
# 17512
# 17513
# 17514
# 17515
# 17516
# 17517
# 17518
# 17519
# 17520
# 17521
# 17522
# 17523
# 17524
# 17525
# 17526
# 17527
# 17528
# 17529
# 17530
# 17531
# 17532
# 17533
# 17534
# 17535
# 17536
# 17537
# 17538
# 17539
# 17540
# 17541
# 17542
# 17543
# 17544
# 17545
# 17546
# 17547
# 17548
# 17549
# 17550
# 17551
# 17552
# 17553
# 17554
# 17555
# 17556
# 17557
# 17558
# 17559
# 17560
# 17561
# 17562
# 17563
# 17564
# 17565
# 17566
# 17567
# 17568
# 17569
# 17570
# 17571
# 17572
# 17573
# 17574
# 17575
# 17576
# 17577
# 17578
# 17579
# 17580
# 17581
# 17582
# 17583
# 17584
# 17585
# 17586
# 17587
# 17588
# 17589
# 17590
# 17591
# 17592
# 17593
# 17594
# 17595
# 17596
# 17597
# 17598
# 17599
# 17600
# 17601
# 17602
# 17603
# 17604
# 17605
# 17606
# 17607
# 17608
# 17609
# 17610
# 17611
# 17612
# 17613
# 17614
# 17615
# 17616
# 17617
# 17618
# 17619
# 17620
# 17621
# 17622
# 17623
# 17624
# 17625
# 17626
# 17627
# 17628
# 17629
# 17630
# 17631
# 17632
# 17633
# 17634
# 17635
# 17636
# ...

# %%
word_contexts.to_csv(os.getcwd().replace('scripts', 'data')+'/word_contexts.csv', index = False)

# %%
no_data
# Out:
# []

# %%
pd.DataFrame(columns = ['index'], data = other).to_csv(os.getcwd().replace('scripts', 'data')+'/full_text_other_error.csv', index = False)

# %%
word_contexts = word_contexts.loc[:696970].drop('context', axis = 1)

# %%
word_contexts
# Out:
#          paper_id                            category   sub_word
# 0               0                            Modeling   modeling
# 1               0                            Modeling   modeling
# 2               0                            Modeling   modeling
# 3               0                            Modeling   modeling
# 4               0                            Modeling   modeling
# ...           ...                                 ...        ...
# 1111686     27399  Infrastructure as a Service (IaaS)  databases
# 1111687     27399  Infrastructure as a Service (IaaS)  databases
# 1111688     27399  Infrastructure as a Service (IaaS)  databases
# 1111689     27399  Infrastructure as a Service (IaaS)  databases
# 1111690     27399  Infrastructure as a Service (IaaS)  databases
#
# [1111691 rows x 3 columns]

# %%
co

# %%
contexts = word_contexts['context'].tolist()

# %%
len(contexts)
# Out:
# 1111711

# %%
pd.DataFrame(columns = ['context'], data = contexts).to_csv(os.getcwd().replace('scripts', 'data')+'/paper_contexts.csv', index = False)

# %%
word_contexts = word_contexts.loc[:692871]

# %%
word_contexts.groupby('paper_id').count()
# Out:
#           category  sub_word
# paper_id
# 0               36        36
# 1              126       126
# 2               40        40
# 3              114       114
# 4               53        53
# ...            ...       ...
# 27395           66        66
# 27396           15        15
# 27397           66        66
# 27398           36        36
# 27399          128       128
#
# [26474 rows x 2 columns]

# %%
word_contexts.groupby('sub_word').count().sort_values('paper_id').tail()
# Out:
#                 paper_id  category
# sub_word
# classification     58098     58098
# algorithm          67620     67620
# regression         77620     77620
# prediction        144998    144998
# simulation        160657    160657

# %%
"""
Plot a time series of year vs the number of articles obtained.

Plot number of country of origin (from affiliations) vs number of publications (we might
be able to create a map of the world that shows the percentages of 

Obtain the top 10 universities and research centers based on number of citations.

Obtain the top 10% of countries that provide the most number of research. You can do 
this based on the categories already set in place.

Create a 2D area graph that shows how the percentage of each of the topics increases
over time. See Fig 3 from reference for guidance.

"""

# %%
journals = pd.read_csv(os.getcwd().replace('scripts', 'data') + '/journals.csv')

# %%
journals
# Out:
#                                               journal  \
# 0                                       HydroResearch
# 1                         Advances in Water Resources
# 2                         Ecohydrology & Hydrobiology
# 3                    Journal of Contaminant Hydrology
# 4                    Journal of Hydrodynamics, Ser. B
# 5               Journal of Hydro-environment Research
# 6                                Journal of Hydrology
# 7              Journal of Hydrology: Regional Studies
# 8                              Journal of Hydrology X
# 9   Physics and Chemistry of the Earth, Part B: Hy...
# 10                      Water Resources and Economics
# 11                       Water Resources and Industry
# 12              Water Resources and Rural Development
# 13                      Agricultural Water Management
# 14            Groundwater for Sustainable Development
# 15               Journal of Water Process Engineering
# ...

# %%
papers = pd.read_csv(os.getcwd().replace('scripts', 'data') + f'/journals/0/fixed_returns.csv')

# %%
papers
# Out:
#            journal                                            authors  \
# 0    HydroResearch  ['J. B. Haman Didier', 'Wilson Y. Fantong', 'G...
# 1    HydroResearch       ['S. Ngo Boum-Nkot', 'B. Nlend', 'J. Etame']
# 2    HydroResearch  ['Ghazala Siraj', 'Haris Hasan Khan', 'Arina K...
# 3    HydroResearch  ['Rowland Adewumi', 'Okechukwu Agbasi', 'Azeez...
# 4    HydroResearch  ['Madhurima Dutta', 'Sunil Saha', 'Prolay Mond...
# ..             ...                                                ...
# 769  HydroResearch  ['M. Rajasekhar', 'G. Sudarsana Raju', 'R. Sid...
# 770  HydroResearch                                  ['Mou Leong Tan']
# 771  HydroResearch               ['Rolland Andrade', 'R. Rangarajan']
# 772  HydroResearch  ['R. Siddi Raju', 'G. Sudarsana Raju', 'M. Raj...
# 773  HydroResearch                 ['P. Tzampoglou', 'C. Loupasakis']
#
#      buzz_id        date                                               name  \
# ...

# %%
buzz = pd.read_csv(os.getcwd().replace('scripts', 'data') + f'/technical_buzzwords.csv')

# %%
class Paper:
    def __init__(self, d, c, n, do, a):
        self.date = d
        self.category=c
        self.name = n
        self.doi = do
        self.authors = a
        
    def __str__(self):
        print("date " + str(self.date))
        print("category " + self.category)
        print("title " + self.name)
        print("doi " + str(self.doi))
        print("authors " + str(self.authors))

# %%
"""?????????????????
num_papers = []
earliest_paper = []
latest_paper = []
for i in range(journals.shape[0]):
    papers = pd.read_csv(os.getcwd().replace('scripts', 'data') + f'/journals/{i}/fixed2papers.csv')

    try:
        times = [[datetime.strptime(papers.iat[j, 3], '%Y-%m-%d'), j] for j in range(papers.shape[0]) if not  pd.isna(papers.iat[j, 3])]

        times = sorted(times)

        num_papers.append(papers.groupby('doi').count().shape[0])
    except Exception as e:
#         print(i)
#         print(papers)
        num_papers.append(None)
    
    
    
    try:
        earliest_p = Paper(times[0][0], buzz.iat[int(papers.iat[times[0][1],2]), 0], papers.iat[times[0][1], 4], papers.iat[times[0][1], 5], papers.iat[times[0][1],1][1:-1].replace("'", '').split(", "))
        
        earliest_paper.append(earliest_p)
        
        latest = Paper(times[-1][0], buzz.iat[int(papers.iat[times[-1][1],2]), 0], papers.iat[times[-1][1], 4], papers.iat[times[-1][1], 5], papers.iat[times[-1][1],1][1:-1].replace("'", '').split(", "))
        
        latest_paper.append(latest)
        
    except Exception as e:
        earliest_paper.append(None)
#         logger.exception(e)
        
        latest_paper.append(None)
"""

# %%
num_papers
# Out:
# [75,
#  158,
#  14,
#  62,
#  0,
#  7,
#  1470,
#  941,
#  104,
#  0,
#  24,
#  117,
#  0,
#  654,
#  42,
#  156,
#  905,
#  0,
#  158,
#  55,
#  27,
#  0,
#  236,
#  261,
#  416,
#  1382,
#  98,
#  221,
#  287]

# %%
fig, ax = plt.subplots(figsize = (18,5))
# plt.figure(figsize=(50, 10))

ax.bar(x = journals['journal'].tolist(), height = num_papers)


plt.xticks(rotation=90)
plt.show()

# %%
fixed2 =pd.read_csv(os.getcwd().replace('scripts', 'data') + '/journals/0/fixed2papers.csv')

# %%
fixed2
# Out:
#            journal                                            authors  \
# 0    HydroResearch  ['J. B. Haman Didier', 'Wilson Y. Fantong', 'G...
# 1    HydroResearch       ['S. Ngo Boum-Nkot', 'B. Nlend', 'J. Etame']
# 2    HydroResearch  ['Ghazala Siraj', 'Haris Hasan Khan', 'Arina K...
# 3    HydroResearch  ['Rowland Adewumi', 'Okechukwu Agbasi', 'Azeez...
# 4    HydroResearch  ['Madhurima Dutta', 'Sunil Saha', 'Prolay Mond...
# ..             ...                                                ...
# 769  HydroResearch  ['M. Rajasekhar', 'G. Sudarsana Raju', 'R. Sid...
# 770  HydroResearch                                  ['Mou Leong Tan']
# 771  HydroResearch               ['Rolland Andrade', 'R. Rangarajan']
# 772  HydroResearch  ['R. Siddi Raju', 'G. Sudarsana Raju', 'M. Raj...
# 773  HydroResearch                 ['P. Tzampoglou', 'C. Loupasakis']
#
#      buzz_id        date                                               name  \
# ...

# %%
fixed2.groupby('buzz_id').count()
# Out:
#          journal  authors  date  name  doi  pii
# buzz_id
# 0             38       38    38    38   38   38
# 1             68       68    68    68   68   68
# 3              4        4     4     4    4    4
# 4              1        1     1     1    1    1
# 5              3        3     3     3    3    3
# 6             36       36    36    36   36   36
# 7             27       27    27    27   27   27
# 8              3        3     3     3    3    3
# 9             50       50    50    50   50   50
# 10            58       56    58    58   58   58
# 11             4        4     4     4    4    4
# 13             4        4     4     4    4    4
# 14            11       11    11    11   11   11
# 15             4        4     4     4    4    4
# 16            67       67    67    67   67   67
# 17             3        3     3     3    3    3
# 18             1        1     1     1    1    1
# 19            22       22    22    22   22   22
# ...

# %%
grouped =fixed2.groupby('buzz_id').count()

# %%
fig, ax = plt.subplots(figsize = (18,5))
# plt.figure(figsize=(50, 10))

ax.bar(x = [buzz.iat[i, 0] for i in range(grouped.shape[0])], height = [grouped.iat[i, 0] for i in range(grouped.shape[0])])


plt.xticks(rotation=90)
plt.show()

# %%
buzz
# Out:
#                               buzzword  \
# 0                                   AI
# 1                             Big Data
# 2                           Blockchain
# 3                                  IoT
# 4                                   VR
# 5                                   AR
# 6                     Machine Learning
# 7                        Cybersecurity
# 8                       Cryptocurrency
# 9                           Automation
# 10                            Modeling
# 11                                 NLP
# 12                   Quantum Computing
# 13                                  5G
# 14                     Cloud Computing
# 15                      Edge Computing
# 16                      Data Analytics
# 17                       Biotechnology
# 18                      Nanotechnology
# 19                 Wearable Technology
# 20          Voice User Interface (VUI)
# 21                             FinTech
# 22                     Neural Networks
# ...

# %%
buzz_cnts = []
for i in range(buzz.shape[0]):
    buzz_cnts.append(0)

for i in range(journals.shape[0]):
    data = pd.read_csv(os.getcwd().replace('scripts', 'data')+f'/journals/{i}/fixed2papers.csv')
    grouped =data.groupby('buzz_id').count()
    
    for j in range(grouped.shape[0]):
        buzz_cnts[j]+= grouped.iat[j,0]

# %%
fig, ax = plt.subplots(figsize = (18,5))
# plt.figure(figsize=(50, 10))

ax.bar(x = [buzz.iat[i, 0] for i in range(len(buzz_cnts))], height = [buzz_cnts[i] for i in range(len(buzz_cnts))])
# ax.set_yscale('log')

plt.xticks(rotation=90)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,5))
# plt.figure(figsize=(50, 10))

ax.bar(x = journals['journal'].tolist(), height = num_papers)


plt.xticks(rotation=90)
plt.show()

# %%
papers.groupby('doi').agg(list)
# Out:
#                                                                         journal  \
# doi
# 10.1016/j.hydres.2019.01.001  [HydroResearch, HydroResearch, HydroResearch, ...
# 10.1016/j.hydres.2019.04.001  [HydroResearch, HydroResearch, HydroResearch, ...
# 10.1016/j.hydres.2019.04.002  [HydroResearch, HydroResearch, HydroResearch, ...
# 10.1016/j.hydres.2019.04.003                     [HydroResearch, HydroResearch]
# 10.1016/j.hydres.2019.06.001  [HydroResearch, HydroResearch, HydroResearch, ...
# ...                                                                         ...
# 10.1016/j.hydres.2023.05.001  [HydroResearch, HydroResearch, HydroResearch, ...
# 10.1016/j.hydres.2023.05.002  [HydroResearch, HydroResearch, HydroResearch, ...
# 10.1016/j.hydres.2023.05.003  [HydroResearch, HydroResearch, HydroResearch, ...
# 10.1016/j.hydres.2023.06.001  [HydroResearch, HydroResearch, HydroResearch, ...
# 10.1016/j.hydres.2023.06.002  [HydroResearch, HydroResearch, HydroResearch, ...
#
# ...

# %%
papers
# Out:
#                                  journal  \
# 0     Environmental Modelling & Software
# 1     Environmental Modelling & Software
# 2     Environmental Modelling & Software
# 3     Environmental Modelling & Software
# 4     Environmental Modelling & Software
# ...                                  ...
# 4742  Environmental Modelling & Software
# 4743  Environmental Modelling & Software
# 4744  Environmental Modelling & Software
# 4745  Environmental Modelling & Software
# 4746  Environmental Modelling & Software
#
#                                                 authors  buzz_id        date  \
# 0     ['Farzad Piadeh', 'Kourosh Behzadian', 'Zoran ...      0.0  2023-07-05
# 1     ['Holger R. Maier', 'Stefano Galelli', 'Greer ...      0.0  2023-07-05
# 2       ['Wenyan Wu', 'Leila Eamen', 'Holger R. Maier']      0.0  2023-07-05
# 3     ['Mohamed Ismaiel Ahmed', 'Kevin Shook', 'Davi...      0.0  2023-07-04
# 4           ['Jasmine B. D. Jaffrés', 'Jessie L. Gray']      0.0  2023-07-04
# ...

# %%
buzz
# Out:
#                               buzzword  \
# 0                                   AI
# 1                             Big Data
# 2                           Blockchain
# 3                                  IoT
# 4                                   VR
# 5                                   AR
# 6                     Machine Learning
# 7                        Cybersecurity
# 8                       Cryptocurrency
# 9                           Automation
# 10                            Modeling
# 11                                 NLP
# 12                   Quantum Computing
# 13                                  5G
# 14                     Cloud Computing
# 15                      Edge Computing
# 16                      Data Analytics
# 17                       Biotechnology
# 18                      Nanotechnology
# 19                 Wearable Technology
# 20          Voice User Interface (VUI)
# 21                             FinTech
# 22                     Neural Networks
# ...

# %%
papers[papers['buzz_id']==37]
# Out:
#                                  journal  \
# 4636  Environmental Modelling & Software
# 4637  Environmental Modelling & Software
# 4638  Environmental Modelling & Software
# 4639  Environmental Modelling & Software
# 4640  Environmental Modelling & Software
# ...                                  ...
# 4836  Environmental Modelling & Software
# 4837  Environmental Modelling & Software
# 4838  Environmental Modelling & Software
# 4839  Environmental Modelling & Software
# 4840  Environmental Modelling & Software
#
#                                                 authors  buzz_id        date  \
# 4636         ['Xin Huang', 'Lei Gao', 'Brett A. Bryan']     37.0  2023-07-07
# 4637  ['Farzad Piadeh', 'Kourosh Behzadian', 'Zoran ...     37.0  2023-07-05
# 4638  ['Holger R. Maier', 'Stefano Galelli', 'Greer ...     37.0  2023-07-05
# 4639    ['Wenyan Wu', 'Leila Eamen', 'Holger R. Maier']     37.0  2023-07-05
# 4640  ['Mohamed Ismaiel Ahmed', 'Kevin Shook', 'Davi...     37.0  2023-07-04
# ...

# %%
papers.groupby('buzz_id').count()
# Out:
#          journal  authors  date  name  doi  pii
# buzz_id
# 0.0          265      265   265   265  265  265
# 1.0          284      284   284   284  284  284
# 2.0           18       18    18    18   18   18
# 3.0           68       68    68    68   68   68
# 4.0           58       58    58    58   58   58
# 5.0           47       47    47    47   47   47
# 6.0          219      219   219   219  219  219
# 7.0          126      126   126   126  126  126
# 8.0           32       32    32    32   32   32
# 9.0          202      202   202   202  202  202
# 10.0         286      286   286   286  286  286
# 11.0         138      138   138   138  138  138
# 12.0           7        7     7     7    7    7
# 13.0          88       88    88    88   88   88
# 14.0         154      154   154   154  154  154
# 15.0          84       84    84    84   84   84
# 16.0         278      278   278   278  278  278
# 17.0          22       22    22    22   22   22
# ...

# %%
h = [papers.groupby('buzz_id').count().iat[i,0] for i in range(buzz.shape[0])]

# %%
fig, ax = plt.subplots(figsize = (18,5))
# plt.figure(figsize=(50, 10))

ax.bar(x = buzz['buzzword'].tolist(), height = h)


plt.xticks(rotation=90)
plt.show()

# %%
x = buzz['buzzword'].tolist()

# %%
for i in range(2018, 2024):
    tmp = papers[papers['year']==i]
    
    tmp.
# Out:
#                                                 journal  \
# year
# 2018  [Environmental Modelling & Software, Environme...
# 2019  [Environmental Modelling & Software, Environme...
# 2020  [Environmental Modelling & Software, Environme...
# 2021  [Environmental Modelling & Software, Environme...
# 2022  [Environmental Modelling & Software, Environme...
# 2023  [Environmental Modelling & Software, Environme...
# nan                                               [nan]
#
#                                                 authors  \
# year
# 2018  [['Argyrios Samourkasidis', 'Evangelia Papouts...
# 2019  [['David N. Barton', 'Håkon Sundt', 'Anders L....
# 2020  [['Saman Razavi', 'Anthony Jakeman', 'Holger R...
# 2021  [['Prado Domercq', 'Antonia Praetorius', 'Matt...
# 2022  [['Seungmin Yoo', 'Junho Song'], ['Alessandro ...
# 2023  [['Xin Huang', 'Lei Gao', 'Brett A. Bryan'], [...
# nan                                               [nan]
#
# ...

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

for i in range(2018, 2019):
    tmp = papers[papers['year']==i]
    
    y = [papers.groupby('buzz_id').count().iat[i,0] for i in range(buzz.shape[0])]
    ax1.bar(x,y)

# %%
buzz
# Out:
#                               buzzword  \
# 0                                   AI
# 1                             Big Data
# 2                           Blockchain
# 3                                  IoT
# 4                                   VR
# 5                                   AR
# 6                     Machine Learning
# 7                        Cybersecurity
# 8                       Cryptocurrency
# 9                           Automation
# 10                            Modeling
# 11                                 NLP
# 12                   Quantum Computing
# 13                                  5G
# 14                     Cloud Computing
# 15                      Edge Computing
# 16                      Data Analytics
# 17                       Biotechnology
# 18                      Nanotechnology
# 19                 Wearable Technology
# 20          Voice User Interface (VUI)
# 21                             FinTech
# 22                     Neural Networks
# ...

# %%
papers
# Out:
#                                  journal  \
# 0     Environmental Modelling & Software
# 1     Environmental Modelling & Software
# 2     Environmental Modelling & Software
# 3     Environmental Modelling & Software
# 4     Environmental Modelling & Software
# ...                                  ...
# 4836  Environmental Modelling & Software
# 4837  Environmental Modelling & Software
# 4838  Environmental Modelling & Software
# 4839  Environmental Modelling & Software
# 4840  Environmental Modelling & Software
#
#                                                 authors  buzz_id        date  \
# 0            ['Xin Huang', 'Lei Gao', 'Brett A. Bryan']      0.0  2023-07-07
# 1     ['Farzad Piadeh', 'Kourosh Behzadian', 'Zoran ...      0.0  2023-07-05
# 2     ['Holger R. Maier', 'Stefano Galelli', 'Greer ...      0.0  2023-07-05
# 3       ['Wenyan Wu', 'Leila Eamen', 'Holger R. Maier']      0.0  2023-07-05
# 4     ['Mohamed Ismaiel Ahmed', 'Kevin Shook', 'Davi...      0.0  2023-07-04
# ...

# %%
import requests

# %%
l = f'https://api.elsevier.com/content/abstract/doi/10.1016/j.ecohyd.2019.10.003?apiKey=10ad507cd08c2ff9d4260ed62ef4cc85&httpAccept=application%2Fjson'
r = requests.get(l)
r.json()
# Out:
# {'abstracts-retrieval-response': {'item': {'ait:process-info': {'ait:status': {'@state': 'update',
#      '@type': 'core',
#      '@stage': 'S300'},
#     'ait:date-delivered': {'@day': '02',
#      '@timestamp': '2020-12-02T03:59:24.000024-05:00',
#      '@year': '2020',
#      '@month': '12'},
#     'ait:date-sort': {'@day': '01', '@year': '2020', '@month': '04'}},
#    'xocs:meta': {'xocs:funding-list': {'@pui-match': 'primary',
#      '@has-funding-info': '1',
#      'xocs:funding': [{'xocs:funding-agency-matched-string': 'AVINA'},
#       {'xocs:funding-agency-matched-string': 'Federal Ministry for the Environment, Nature Conservation and Nuclear Safety of Germany'},
#       {'xocs:funding-agency-matched-string': 'Ministry of Foreign Affairs',
#        'xocs:funding-agency': 'Ministerie van Buitenlandse Zaken',
#        'xocs:funding-agency-id': 'http://data.elsevier.com/vocabulary/SciValFunders/501100007729',
# ...

# %%
papers[papers['year']=='2018'].groupby('buzz_id').count()
# Out:
#          journal  authors  date  name  doi  pii  year
# buzz_id
# 0.0           27       27    27    27   27   27    27
# 1.0           29       29    29    29   29   29    29
# 3.0            8        8     8     8    8    8     8
# 4.0            5        5     5     5    5    5     5
# 5.0            5        5     5     5    5    5     5
# 6.0           18       18    18    18   18   18    18
# 7.0           12       12    12    12   12   12    12
# 8.0            3        3     3     3    3    3     3
# 9.0           20       20    20    20   20   20    20
# 10.0          29       29    29    29   29   29    29
# 12.0           2        2     2     2    2    2     2
# 13.0           9        9     9     9    9    9     9
# 14.0          18       18    18    18   18   18    18
# 15.0          10       10    10    10   10   10    10
# 16.0          29       29    29    29   29   29    29
# 17.0           1        1     1     1    1    1     1
# ...

# %%
import seaborn as sns
# fig, ax = plt.subplots(figsize = (18,5))
g = sns.catplot(data=sorted_d, x='topic', y='data', row='Year',
            kind='bar', height=2, aspect=10)
# plt.xticks(rotation=45)

# %%
tmp.iat[0,2].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 tmp.iat[0,2].dtype()
#
# TypeError: 'numpy.dtype[float64]' object is not callable

# %%
papers
# Out:
#                                  journal  \
# 0     Environmental Modelling & Software
# 1     Environmental Modelling & Software
# 2     Environmental Modelling & Software
# 3     Environmental Modelling & Software
# 4     Environmental Modelling & Software
# ...                                  ...
# 4836  Environmental Modelling & Software
# 4837  Environmental Modelling & Software
# 4838  Environmental Modelling & Software
# 4839  Environmental Modelling & Software
# 4840  Environmental Modelling & Software
#
#                                                 authors  buzz_id        date  \
# 0            ['Xin Huang', 'Lei Gao', 'Brett A. Bryan']      0.0  2023-07-07
# 1     ['Farzad Piadeh', 'Kourosh Behzadian', 'Zoran ...      0.0  2023-07-05
# 2     ['Holger R. Maier', 'Stefano Galelli', 'Greer ...      0.0  2023-07-05
# 3       ['Wenyan Wu', 'Leila Eamen', 'Holger R. Maier']      0.0  2023-07-05
# 4     ['Mohamed Ismaiel Ahmed', 'Kevin Shook', 'Davi...      0.0  2023-07-04
# ...

# %%
papers[papers['year']=='2018']
# Out:
#                                  journal  \
# 239   Environmental Modelling & Software
# 240   Environmental Modelling & Software
# 241   Environmental Modelling & Software
# 242   Environmental Modelling & Software
# 243   Environmental Modelling & Software
# ...                                  ...
# 4836  Environmental Modelling & Software
# 4837  Environmental Modelling & Software
# 4838  Environmental Modelling & Software
# 4839  Environmental Modelling & Software
# 4840  Environmental Modelling & Software
#
#                                                 authors  buzz_id        date  \
# 239   ['Argyrios Samourkasidis', 'Evangelia Papoutso...      0.0  2018-11-17
# 240   ['Christopher D. Knightes', 'Robert B. Ambrose...      0.0  2018-11-05
# 241   ['Majid Shadman Roodposhti', 'Jagannath Aryal'...      0.0  2018-10-29
# 242   ['Saman Razavi', 'Razi Sheikholeslami', 'Amin ...      0.0  2018-10-28
# 243   ['Ana Stritih', 'Peter Bebi', 'Adrienne Grêt-R...      0.0  2018-09-19
# ...

# %%
grouped = papers[papers['year']=='2018'].groupby('buzz_id').count()

# %%
grouped
# Out:
#          journal  authors  date  name  doi  pii  year
# buzz_id
# 0.0           27       27    27    27   27   27    27
# 1.0           29       29    29    29   29   29    29
# 3.0            8        8     8     8    8    8     8
# 4.0            5        5     5     5    5    5     5
# 5.0            5        5     5     5    5    5     5
# 6.0           18       18    18    18   18   18    18
# 7.0           12       12    12    12   12   12    12
# 8.0            3        3     3     3    3    3     3
# 9.0           20       20    20    20   20   20    20
# 10.0          29       29    29    29   29   29    29
# 12.0           2        2     2     2    2    2     2
# 13.0           9        9     9     9    9    9     9
# 14.0          18       18    18    18   18   18    18
# 15.0          10       10    10    10   10   10    10
# 16.0          29       29    29    29   29   29    29
# 17.0           1        1     1     1    1    1     1
# ...

# %%
hs = []

# %%
for i in range(38):
    if i not in grouped.index.tolist():
        hs.append(0)
    else:
        hs.append(grouped.loc[i]['journal'])

# %%
fig, ax = plt.subplots(figsize = (18,5))
# plt.figure(figsize=(50, 10))

ax.bar(x = buzz['buzzword'].tolist(), height = hs)
plt.title('2018')

plt.xticks(rotation=90)
plt.show()
