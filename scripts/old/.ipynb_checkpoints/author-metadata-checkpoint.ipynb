# %%
import os

import selenium
from selenium import webdriver
import requests
import re
from bs4 import BeautifulSoup as bs
import pandas as pd
import time
from selenium.webdriver.common.by import By
import xmltodict as xmld
import time

# %%
keys = ["4f01916778617ee8304d5e19455d246c",
"320b5bf579101451e8df63604cb0c85e",
"b06e9c4e40f14fa42031fd1f9b3a0b65",
"9bd996bd34d6da7624a4f94004ea78d0",
"7f93afd8e376e6bb5fb5bab91cf09621",
"2317c52bbc55de588eef6ee64bfcc184",
"852dec0992ac8fce4128de56663bdb14",
"c334541681f71c2059c29467c0d70d07",
"a06b94f351d042ccec3a28009009547d",
"40d9432fbad94893714ed73c005ef04f"]

# %%
papers = pd.read_csv(os.getcwd().replace('scripts', 'data')+'/metadata_accessible.csv')

# %%
papers
# Out:
#        journal_id  volume_id  year  \
# 0               1          0  2023
# 1               1          0  2023
# 2               1          0  2023
# 3               1          0  2023
# 4               1          0  2023
# ...           ...        ...   ...
# 27395          28         68  2018
# 27396          28         68  2018
# 27397          28         68  2018
# 27398          28         68  2018
# 27399          28         68  2018
#
#                                                     link  \
# 0      https://www.sciencedirect.com/science/article/...
# 1      https://www.sciencedirect.com/science/article/...
# 2      https://www.sciencedirect.com/science/article/...
# 3      https://www.sciencedirect.com/science/article/...
# 4      https://www.sciencedirect.com/science/article/...
# ...                                                  ...
# 27395  https://www.sciencedirect.com/science/article/...
# 27396  https://www.sciencedirect.com/science/article/...
# ...

# %%
all_authors = pd.read_csv(os.getcwd().replace('scripts', 'data')+'/author_metadata.csv')

# %%
no_data = pd.read_csv(os.getcwd().replace('scripts', 'data')+'/missing_authors.csv')['au_id'].tolist()

# %%
processed = set(pd.read_csv(os.getcwd().replace('scripts', 'data')+'/author_metadata.csv')['id'].tolist())

# %%
keyi = 0
i = 20857
while i < papers.shape[0]:
    print(i)
    auth_ids = papers.loc[i]['authors'].split(', ')
    
#     print(set(auth_ids))
    
    j = 0
    
    while j < len(set(auth_ids)):
        subt = False
        
        auid = auth_ids[j]
        if auid not in processed:
            key = keys[keyi]
            
            js = requests.get(f"https://api.elsevier.com/content/author/author_id/{auid}?apiKey={key}&httpAccept=application%2Fjson")
            r = js.json()

#             print(r)
#             print("----------------")
            try:
                eid = r['author-retrieval-response'][0]['coredata']['eid']

                citations = r['author-retrieval-response'][0]['coredata']['citation-count']

                citedby = r['author-retrieval-response'][0]['coredata']['cited-by-count']

                names = r['author-retrieval-response'][0]['author-profile']['preferred-name']

                name = names['given-name'] + ' '+ names['surname']

                all_authors.loc[len(all_authors.index)] = [auid, eid, name, citedby, citations]

                processed.add(auid)
            except Exception as e:
                print(str(e))
                no_data.append(auid)
                j+=1
            keyi = (keyi+1)%10
        j+=1
    i+=1
# Out:
# 20857
# 20858
# 20859
# 20860
# 20861
# 20862
# 20863
# 20864
# 20865
# 20866
# 20867
# 20868
# 20869
# 20870
# 20871
# 20872
# 20873
# 20874
# 20875
# 20876
# 20877
# 20878
# 20879
# 20880
# 0
# 20881
# 20882
# 20883
# 20884
# 20885
# 20886
# 20887
# 20888
# 20889
# 20890
# 20891
# 20892
# 20893
# 20894
# 20895
# 20896
# 20897
# 20898
# 20899
# 20900
# 20901
# 20902
# 20903
# 20904
# 20905
# 20906
# 20907
# 20908
# 20909
# 20910
# 20911
# 20912
# 20913
# 20914
# 20915
# 20916
# 20917
# 20918
# 20919
# 20920
# 20921
# 20922
# 20923
# 20924
# 20925
# 20926
# 20927
# 20928
# 20929
# 20930
# 20931
# 20932
# 20933
# 20934
# 20935
# 20936
# 20937
# 20938
# 20939
# 20940
# 20941
# 20942
# 20943
# 20944
# 20945
# 20946
# 20947
# 20948
# 20949
# 20950
# 20951
# 20952
# 20953
# 20954
# 20955
# 20956
# 20957
# 20958
# 20959
# 20960
# 20961
# 20962
# 20963
# 20964
# 20965
# 20966
# 20967
# 20968
# 20969
# 20970
# 20971
# 20972
# 20973
# 20974
# 20975
# 20976
# 20977
# 20978
# 20979
# 20980
# ...

# %%
no_data
# Out:
# [57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57566648500,
#  57218628827,
#  57218628827,
#  57700023400,
#  57768087400,
#  57273371400,
#  57939188900,
#  57910558500,
#  58126192000,
#  57840784900,
#  58018686900,
#  57214095389,
#  57962774100,
#  57866563100,
#  57869283500,
#  57710406900,
#  55938288400,
#  57840476100,
#  44161021100,
#  57212848690,
#  57403082500,
#  57218455611,
#  55744609000,
#  '57206274266',
#  '56412009100',
#  '58177927500',
#  '57223305319',
#  '57218582957',
#  '57208328510',
#  '58242500900',
#  '57211190008',
#  '58038862400',
#  '57840784900',
#  '57840784900',
#  '40762579200',
#  '57690736600',
#  '57872473400',
#  '57852357800',
#  '56435801200',
#  '57411850900',
#  '57211649796',
#  '57403979000',
#  '57217389900',
#  '57217389900',
# ...

# %%
all_authors
# Out:
#                 id                 eid                            name  \
# 0      58307014400  9-s2.0-58307014400           Rasoul Soufi Noughabi
# 1      36008901600  9-s2.0-36008901600          Seyed Hossein Mansouri
# 2      26635952600  9-s2.0-26635952600                      Amir Raoof
# 3      53984251100  9-s2.0-53984251100        Vasileios E. Katzourakis
# 4      35610240400  9-s2.0-35610240400  Constantinos V. Chrysikopoulos
# ...            ...                 ...                             ...
# 91446  14622887900  9-s2.0-14622887900                     Mark Musall
# 91447  52365181700  9-s2.0-52365181700             Céline Vaneeckhaute
# 91448  22957372900  9-s2.0-22957372900               Filip H.A. Claeys
# 91449   7005864023   9-s2.0-7005864023                 Filip M.G. Tack
# 91450   8983405600   9-s2.0-8983405600                      Erik Meers
#
#       cited-by citations
# 0            0         0
# 1          743       903
# 2         1131      1475
# ...

# %%
all_authors[all_authors['id'] == "57193411980"]
# Out:
#                 id                 eid       name cited-by citations
# 44295  57193411980  9-s2.0-57193411980  Yang Wang      190       201

# %%
papers.iloc[13126]['authors']
# Out:
# '56115489500, 57983609700, 57982666900, 57226545435, 57537578800, 55046395700, 57193411980'

# %%
all_authors.to_csv(os.getcwd().replace('scripts', 'data')+'/author_metadata.csv', index = False)

# %%
pd.DataFrame(columns = ['au_id'], data = no_data).to_csv(os.getcwd().replace('scripts', 'data')+'/missing_authors.csv', index = False)

# %%
len(no_data)
# Out:
# 39321
