# %%
import os
import selenium
from selenium import webdriver
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Safari()
for i in range(25,29):
    #each journal
    curr_volumes = pd.read_csv(os.getcwd().replace('scripts', 'data')+'/journals/'+str(i)+'/volumes.csv')
    #df of all papers in journal
#     df = pd.DataFrame(columns = ['vol_index', 'paper_link', 'doi'])
    df = pd.DataFrame(columns = ['vol_index', 'paper_link'])
    
    for k in range(curr_volumes.shape[0]):
        vol_link = curr_volumes.iat[k, 1]
        print(vol_link)
        try:
            papers = getPapers(vol_link)
        except Exception:
            driver.close()
            driver = webdriver.Safari()
            papers = getPapers(vol_link)
        
#         dois = []
        
#         for j in range(len(papers)):
#             dois.append(scrapeDOI(papers[j]))
            
#             df.loc[len(df.index)] = [k, papers[j], dois[j]]
        for j in range(len(papers)):
            df.loc[len(df.index)] = [k, papers[j]]
            
    
    df.to_csv(os.getcwd().replace('scripts', 'data')+'/journals/'+str(i)+'/papers.csv', index = False)
# Out:
# https://www.sciencedirect.com/journal/ocean-engineering/vol/284/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/283/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/282/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/281/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/280/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/279/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/278/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/277/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/276/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/275/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/274/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/273/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/272/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/271/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/270/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/269/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/268/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/267/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/266/part/P5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/266/part/P4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/266/part/P3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/266/part/P2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/266/part/P1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/265/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/264/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/263/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/262/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/261/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/260/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/259/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/258/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/257/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/256/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/255/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/254/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/253/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/252/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/251/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/250/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/249/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/248/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/247/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/246/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/245/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/244/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/243/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/242/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/241/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/240/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/239/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/238/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/237/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/236/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/235/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/234/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/233/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/232/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/231/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/230/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/229/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/228/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/227/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/226/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/225/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/224/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/223/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/222/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/221/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/220/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/219/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/218/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/217/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/216/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/215/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/214/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/213/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/212/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/211/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/210/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/209/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/208/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/207/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/206/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/205/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/204/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/203/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/202/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/201/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/200/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/199/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/198/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/197/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/196/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/195/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/194/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/193/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/192/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/191/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/190/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/189/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/188/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/187/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/186/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/185/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/184/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/183/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/182/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/181/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/180/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/179/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/178/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/177/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/176/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/175/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/174/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/173/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/172/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/171/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/170/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/169/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/168/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/167/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/166/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/165/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/164/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/163/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/162/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/161/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/160/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/159/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/158/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/157/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/156/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/155/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/154/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/153/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/152/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/151/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/150/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/149/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/148/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/147/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/146/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/145/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/144/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/143/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/142/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/141/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/140/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/139/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/138/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/137/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/136/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/135/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/134/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/133/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/132/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/131/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/130/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/129/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/128/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/127/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/126/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/125/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/124/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/124/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/123/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/122/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/121/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/120/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/119/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/118/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/117/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/116/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/115/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/114/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/113/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/112/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/111/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/110/part/PB
# https://www.sciencedirect.com/journal/ocean-engineering/vol/110/part/PA
# https://www.sciencedirect.com/journal/ocean-engineering/vol/109/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/108/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/107/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/106/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/105/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/104/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/103/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/102/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/101/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/100/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/99/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/98/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/97/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/96/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/95/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/94/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/93/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/92/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/91/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/90/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/89/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/88/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/87/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/86/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/85/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/84/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/83/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/82/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/81/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/80/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/79/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/78/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/77/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/76/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/75/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/74/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/73/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/72/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/71/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/70/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/69/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/68/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/67/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/66/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/65/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/64/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/63/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/62/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/61/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/60/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/59/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/58/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/57/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/56/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/55/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/54/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/53/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/52/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/51/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/50/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/49/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/48/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/47/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/46/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/45/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/44/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/43/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/42/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/41/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/40/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/39/suppl/C
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/38/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/37/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/15
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/12
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/9
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/6
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/36/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/35/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/34/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/33/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/13
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#      12 try:
# ---> 13     papers = getPapers(vol_link)
#      14 except Exception:
#
# Input In [3], in getPapers(volume)
#       1 def getPapers(volume):
#       2 #     driver = webdriver.Safari()
# ----> 4     driver.get(volume)
#       5     return [p.get_attribute('href') for p in driver.find_elements(By.CLASS_NAME,'article-content-title')]
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.get(self, url)
#     439 """
#     440 Loads a web page in the current browser session.
#     441 """
# --> 442 self.execute(Command.GET, {'url': url})
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message:
#
#
# During handling of the above exception, another exception occurred:
#
# InvalidSessionIdException                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#      13     papers = getPapers(vol_link)
#      14 except Exception:
# ---> 15     driver.close()
#      16     driver = webdriver.Safari()
#      17     papers = getPapers(vol_link)
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:943, in WebDriver.close(self)
#     934 def close(self) -> None:
#     935     """
#     936     Closes the current window.
#     937
#    (...)
#     941             driver.close()
#     942     """
# --> 943     self.execute(Command.CLOSE)
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message:

# %%
df[df['vol_index']==326]
# Out:
#        vol_index                                         paper_link
# 12525        326  https://www.sciencedirect.com/science/article/...
# 12526        326  https://www.sciencedirect.com/science/article/...
# 12527        326  https://www.sciencedirect.com/science/article/...
# 12528        326  https://www.sciencedirect.com/science/article/...
# 12529        326  https://www.sciencedirect.com/science/article/...
# 12530        326  https://www.sciencedirect.com/science/article/...
# 12531        326  https://www.sciencedirect.com/science/article/...
# 12532        326  https://www.sciencedirect.com/science/article/...
# 12533        326  https://www.sciencedirect.com/science/article/...
# 12534        326  https://www.sciencedirect.com/science/article/...
# 12535        326  https://www.sciencedirect.com/science/article/...
# 12536        326  https://www.sciencedirect.com/science/article/...
# 12537        326  https://www.sciencedirect.com/science/article/...
# 12538        326  https://www.sciencedirect.com/science/article/...
# 12539        326  https://www.sciencedirect.com/science/article/...

# %%
df= df[:12525]

# %%
driver = webdriver.Safari()
#each journal
curr_volumes = pd.read_csv(os.getcwd().replace('scripts', 'data')+'/journals/'+str(25)+'/volumes.csv')
    #df of all papers in journal
#     df = pd.DataFrame(columns = ['vol_index', 'paper_link', 'doi'])
# df = pd.DataFrame(columns = ['vol_index', 'paper_link'])
    
for k in range(326,curr_volumes.shape[0]):
    vol_link = curr_volumes.iat[k, 1]
    print(vol_link)
    try:
        papers = getPapers(vol_link)
    except Exception:
        driver.close()
        driver = webdriver.Safari()
        papers = getPapers(vol_link)
        
#         dois = []
        
#         for j in range(len(papers)):
#             dois.append(scrapeDOI(papers[j]))
            
#             df.loc[len(df.index)] = [k, papers[j], dois[j]]
    for j in range(len(papers)):
        df.loc[len(df.index)] = [k, papers[j]]
            
    
    df.to_csv(os.getcwd().replace('scripts', 'data')+'/journals/'+str(i)+'/papers.csv', index = False)
# Out:
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/14
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# /var/folders/sw/rc481v691q5883ld6bm6jzq80000gn/T/ipykernel_12655/3332178043.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[len(df.index)] = [k, papers[j]]
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/32/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/31/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/18
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/15
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/12
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/9
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/6
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/15
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/12
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/9
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/6
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/29/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/12
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/9
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/6
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/28/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/12
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/9
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/6
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/27/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/18
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/15
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/12
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/9
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/8
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/7
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/6
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/5
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/4
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/3
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/2
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/1
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/18
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/17
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/16
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/15
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/14
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/13
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/12
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/11
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/10
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/9
# https://www.sciencedirect.com/journal/ocean-engineering/vol/30/issue/8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 8>()
#      10 print(vol_link)
#      11 try:
# ---> 12     papers = getPapers(vol_link)
#      13 except Exception:
#      14     driver.close()
#
# Input In [3], in getPapers(volume)
#       1 def getPapers(volume):
#       2 #     driver = webdriver.Safari()
# ----> 4     driver.get(volume)
#       5     return [p.get_attribute('href') for p in driver.find_elements(By.CLASS_NAME,'article-content-title')]
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:442, in WebDriver.get(self, url)
#     438 def get(self, url: str) -> None:
#     439     """
#     440     Loads a web page in the current browser session.
#     441     """
# --> 442     self.execute(Command.GET, {'url': url})
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     425         params['sessionId'] = self.session_id
#     427 params = self._wrap_value(params)
# --> 428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
#     430     self.error_handler.check_response(response)
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:347, in RemoteConnection.execute(self, command, params)
#     345 data = utils.dump_json(params)
#     346 url = f"{self._url}{path}"
# --> 347 return self._request(command_info[0], url, body=data)
#
# File /usr/local/lib/python3.9/site-packages/selenium/webdriver/remote/remote_connection.py:369, in RemoteConnection._request(self, method, url, body)
#     366     body = None
#     368 if self.keep_alive:
# --> 369     response = self._conn.request(method, url, body=body, headers=headers)
#     370     statuscode = response.status
#     371 else:
#
# File /usr/local/lib/python3.9/site-packages/urllib3/request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File /usr/local/lib/python3.9/site-packages/urllib3/request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File /usr/local/lib/python3.9/site-packages/urllib3/poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/local/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/local/Cellar/python@3.9/3.9.17/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File /usr/local/Cellar/python@3.9/3.9.17/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File /usr/local/Cellar/python@3.9/3.9.17/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.9/3.9.17/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
curr_volumes.iat[412,1]
# Out:
# 'https://www.sciencedirect.com/journal/water-research/vol/36/issue/17'

# %%
df = df.drop(df.index[15913:15939])

# %%
df[df['vol_index']==412]
# Out:
#        vol_index                                         paper_link
# 15913        412  https://www.sciencedirect.com/science/article/...
# 15914        412  https://www.sciencedirect.com/science/article/...
# 15915        412  https://www.sciencedirect.com/science/article/...
# 15916        412  https://www.sciencedirect.com/science/article/...
# 15917        412  https://www.sciencedirect.com/science/article/...
# 15918        412  https://www.sciencedirect.com/science/article/...
# 15919        412  https://www.sciencedirect.com/science/article/...
# 15920        412  https://www.sciencedirect.com/science/article/...
# 15921        412  https://www.sciencedirect.com/science/article/...
# 15922        412  https://www.sciencedirect.com/science/article/...
# 15923        412  https://www.sciencedirect.com/science/article/...
# 15924        412  https://www.sciencedirect.com/science/article/...
# 15925        412  https://www.sciencedirect.com/science/article/...
# 15926        412  https://www.sciencedirect.com/science/article/...
# 15927        412  https://www.sciencedirect.com/science/article/...
# 15928        412  https://www.sciencedirect.com/science/article/...
# 15929        412  https://www.sciencedirect.com/science/article/...
# 15930        412  https://www.sciencedirect.com/science/article/...
# 15931        412  https://www.sciencedirect.com/science/article/...
# 15932        412  https://www.sciencedirect.com/science/article/...
# 15933        412  https://www.sciencedirect.com/science/article/...
# 15934        412  https://www.sciencedirect.com/science/article/...
# 15935        412  https://www.sciencedirect.com/science/article/...
# 15936        412  https://www.sciencedirect.com/science/article/...
# 15937        412  https://www.sciencedirect.com/science/article/...
# 15938        412  https://www.sciencedirect.com/science/article/...

# %%
df
# Out:
#       vol_index                                         paper_link
# 0             0  https://www.sciencedirect.com/science/article/...
# 1             0  https://www.sciencedirect.com/science/article/...
# 2             0  https://www.sciencedirect.com/science/article/...
# 3             0  https://www.sciencedirect.com/science/article/...
# 4             0  https://www.sciencedirect.com/science/article/...
# ...         ...                                                ...
# 9102        153  https://www.sciencedirect.com/science/article/...
# 9103        153  https://www.sciencedirect.com/science/article/...
# 9104        153  https://www.sciencedirect.com/science/article/...
# 9105        153  https://www.sciencedirect.com/science/article/...
# 9106        153  https://www.sciencedirect.com/science/article/...
#
# [9107 rows x 2 columns]

# %%
df.to_csv(os.getcwd().replace('scripts', 'data')+'/journals/16/papers.csv', index = False)

# %%
def getPapers(volume):
#     driver = webdriver.Safari()
    
    driver.get(volume)
    return [p.get_attribute('href') for p in driver.find_elements(By.CLASS_NAME,'article-content-title')]

# %%
def scrapeDOI(paper):
#     driver = webdriver.Safari()
    driver.get(paper)
    
    return driver.find_element(By.CLASS_NAME, 'doi').get_attribute('href').split('doi.org/')[1]

# %%
def getTitles(volume):
#     driver = webdriver.Safari()
    
    driver.get(volume)
    return [p.get_attribute('innerHTML') for p in driver.find_elements(By.CLASS_NAME,'js-article-title')]
